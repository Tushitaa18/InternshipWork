# %%
# !pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 18.8 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sweetviz as sv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/CombinedSalesData 2009-2011.xlsx'
try:

    df = pd.read_excel(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File loaded successfully.

# %%
df.head()
# Out:
#   InvoiceNo StockCode                       Description  Quantity  \
# 0    564754     21068   VINTAGE BILLBOARD LOVE/HATE MUG         1
# 1    564754     21221       SET/4 BADGES CUTE CREATURES         1
# 2    564754     21232    STRAWBERRY CERAMIC TRINKET BOX         1
# 3    564754     21379  CAMPHOR WOOD PORTOBELLO MUSHROOM         1
# 4    564754     21774   DECORATIVE CATS BATHROOM BOTTLE         1
#
#       InvoiceDateTime  UnitPrice  Customer ID         Country InvoiceDate  \
# 0 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
# 1 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
# 2 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
# 3 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
# 4 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
#
#   InvoiceTime  Year   Month
# 0    10:29:00  2011  August
# 1    10:29:00  2011  August
# 2    10:29:00  2011  August
# ...

# %%
df.shape
# Out:
# (932922, 12)

# %%
df.isnull().sum()
# Out:
# InvoiceNo               0
# StockCode               0
# Description          1454
# Quantity                0
# InvoiceDateTime         0
# UnitPrice               0
# Customer ID        135037
# Country                 0
# InvoiceDate             0
# InvoiceTime             0
# Year                    0
# Month                   0
# dtype: int64

# %%
rows_missing_values = df[df.isnull().any(axis=1)]
df_cleaned = df.dropna()

# %%
df_cleaned.head()
# Out:
#       InvoiceNo StockCode                Description  Quantity  \
# 74745    564764       DOT             DOTCOM POSTAGE         1
# 74746    565383     22896      PEG BAG APPLES DESIGN         1
# 74747    565383     22939  ADULT APRON APPLE DELIGHT         1
# 74748    565383       DOT             DOTCOM POSTAGE         1
# 74749    566217       DOT             DOTCOM POSTAGE         1
#
#           InvoiceDateTime  UnitPrice  Customer ID         Country InvoiceDate  \
# 74745 2011-08-30 10:49:00      11.17      14096.0  United Kingdom  2011-08-30
# 74746 2011-09-02 15:45:00       4.96      14096.0  United Kingdom  2011-09-02
# 74747 2011-09-02 15:45:00      10.79      14096.0  United Kingdom  2011-09-02
# 74748 2011-09-02 15:45:00      16.46      14096.0  United Kingdom  2011-09-02
# 74749 2011-09-09 15:17:00      13.16      14096.0  United Kingdom  2011-09-09
#
#       InvoiceTime  Year      Month
# 74745    10:49:00  2011     August
# 74746    15:45:00  2011  September
# ...

# %%
df_cleaned.shape
# Out:
# (797885, 12)

# %%
df_cleaned.isnull().sum()
# Out:
# InvoiceNo          0
# StockCode          0
# Description        0
# Quantity           0
# InvoiceDateTime    0
# UnitPrice          0
# Customer ID        0
# Country            0
# InvoiceDate        0
# InvoiceTime        0
# Year               0
# Month              0
# dtype: int64

# %%
rows_missing_values.head()
# Out:
#   InvoiceNo StockCode                       Description  Quantity  \
# 0    564754     21068   VINTAGE BILLBOARD LOVE/HATE MUG         1
# 1    564754     21221       SET/4 BADGES CUTE CREATURES         1
# 2    564754     21232    STRAWBERRY CERAMIC TRINKET BOX         1
# 3    564754     21379  CAMPHOR WOOD PORTOBELLO MUSHROOM         1
# 4    564754     21774   DECORATIVE CATS BATHROOM BOTTLE         1
#
#       InvoiceDateTime  UnitPrice  Customer ID         Country InvoiceDate  \
# 0 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
# 1 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
# 2 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
# 3 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
# 4 2011-08-30 10:29:00       2.46          NaN  United Kingdom  2011-08-30
#
#   InvoiceTime  Year   Month
# 0    10:29:00  2011  August
# 1    10:29:00  2011  August
# 2    10:29:00  2011  August
# ...

# %%
rows_missing_values.shape
# Out:
# (135037, 12)

# %%
# !pip install autoviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 57.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 63.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 98.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.3
#     Uninstalling xgboost-2.0.3:
#       Successfully uninstalled xgboost-2.0.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
# ...

# %%
df.to_csv('CombinedSales 2009-2011.csv')
df_cleaned.to_csv('Cleaned CombinedSales 2009-2011.csv')
rows_missing_values.to_csv('Missing Values.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV= AutoViz_Class()
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %% [markdown]
# It is evident that there are missing customer id in the data

# %%
# %matplotlib inline
filename = "CombinedSales 2009-2011.csv"

df= AV.AutoViz(
    filename
)
# Out:
#     max_rows_analyzed is smaller than dataset shape 932922...
#         randomly sampled 150000 rows from read CSV file
# Shape of your Data Set loaded: (150000, 13)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Removing ['InvoiceNo'] column(s) due to mixed data type detected...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  3
#     Number of Date Time Columns =  1
#     Number of ID Columns =  1
# ...

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype(str)
df['StockCode'] = df['StockCode'].astype(str)
my_report = sv.analyze(df)
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
